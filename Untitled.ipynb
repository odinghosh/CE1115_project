# %%
import pandas as pd
import requests
import seaborn as sb
import matplotlib.pyplot as plt

# %%
x = requests.get('https://api.covidtracking.com/v1/us/daily.csv')

# %%
data_state = pd.read_csv('https://api.covidtracking.com/v1/states/ca/daily.csv')

# %%
death = pd.DataFrame(data_state['deathIncrease'])
date = pd.DataFrame(data_state['date'])
death.size
# Out:
# 369

# %%
def get_average_new_deaths(state_name):
    data_state = pd.read_csv('https://api.covidtracking.com/v1/states/' + state_name +'/daily.csv')
    death = pd.DataFrame(data_state['deathIncrease'])
    days = []
    for i in range(death.size, 0, -1):
        days.append(i)

    death.insert(0, 'days', days)
    average_sum = 0
    for i in range(0, death['deathIncrease'].size):
        average_sum += death['deathIncrease'][i];
    
    return (average_sum/death.size)

# %%
days = []
for i in range(death.size, 0, -1):
    days.append(i)

death.insert(0, 'days', days)

# %%
f = plt.figure(figsize=(16,8))
sb.lineplot(data = death, x ='days', y ='deathIncrease')
# Out:
# <AxesSubplot:xlabel='days', ylabel='deathIncrease'>

# %%
death['deathIncrease'].size
average_sum = 0
for i in range(0, death['deathIncrease'].size):
    average_sum += death['deathIncrease'][i];
    
print(average_sum/death.size)
# Out:
# 73.33875338753387

# %%
state_names = pd.read_html('https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States')

# %%
state_names = state_names[0]

# %%
state_names = state_names.iloc[:,[0,1]]

# %%
state_names = state_names['Flag, name andpostal abbreviation[12]']

# %%
state_names = state_names.set_index('Flag, name andpostal abbreviation[12]')

# %%
state_names = state_names.to_dict()['Flag, name andpostal abbreviation[12].1']

# %%
removal_list = []
for key,value in state_names.items():
    state_names[key] = value.lower()
    if(key[-1] == ']'):
        removal_list.append(key)

# %%
for i in removal_list:
    value = state_names[i]
    state_names.pop(i)
    state_names[i[:-3]] = value

# %%
state_names
# Out:
# {'Alabama': 'al',
#  'Alaska': 'ak',
#  'Arizona': 'az',
#  'Arkansas': 'ar',
#  'California': 'ca',
#  'Colorado': 'co',
#  'Connecticut': 'ct',
#  'Delaware': 'de',
#  'Florida': 'fl',
#  'Georgia': 'ga',
#  'Hawaii': 'hi',
#  'Idaho': 'id',
#  'Illinois': 'il',
#  'Indiana': 'in',
#  'Iowa': 'ia',
#  'Kansas': 'ks',
#  'Louisiana': 'la',
#  'Maine': 'me',
#  'Maryland': 'md',
#  'Michigan': 'mi',
#  'Minnesota': 'mn',
#  'Mississippi': 'ms',
#  'Missouri': 'mo',
#  'Montana': 'mt',
#  'Nebraska': 'ne',
#  'Nevada': 'nv',
#  'New Hampshire': 'nh',
#  'New Jersey': 'nj',
#  'New Mexico': 'nm',
#  'New York': 'ny',
#  'North Carolina': 'nc',
#  'North Dakota': 'nd',
#  'Ohio': 'oh',
#  'Oklahoma': 'ok',
#  'Oregon': 'or',
#  'Rhode Island': 'ri',
#  'South Carolina': 'sc',
#  'South Dakota': 'sd',
#  'Tennessee': 'tn',
#  'Texas': 'tx',
#  'Utah': 'ut',
#  'Vermont': 'vt',
#  'Washington': 'wa',
#  'West Virginia': 'wv',
#  'Wisconsin': 'wi',
#  'Wyoming': 'wy',
#  'Kentucky': 'ky',
#  'Massachusetts': 'ma',
#  'Pennsylvania': 'pa',
#  'Virginia': 'va'}

# %%
get_average_new_deaths(state_names['Alabama'])
# Out:
# 13.863387978142077

# %%
average_death_dict = {}
for name in state_names.keys():
    average_deaths = get_average_new_deaths(state_names[name])
    average_death_dict[name] = average_deaths
    print(name)
# Out:
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Louisiana
# Maine
# Maryland
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Washington
# West Virginia
# Wisconsin
# Wyoming
# Kentucky
# Massachusetts
# Pennsylvania
# Virginia

# %%
population_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population')

# %%
population_data = population_data[0]

# %%
population_data = population_data.iloc[:,[2,3]]

# %%
population_data = list(population_data.set_index('State or territory').to_dict().values())[0]

# %%
for i in average_death_dict.keys():
    average_death_dict[i] = int(average_death_dict[i])/int(population_data[(i,)])

# %%
for i in average_death_dict.keys():
    average_death_dict[i] = average_death_dict[i]*1000000

# %%
average_death_dict
# Out:
# {'Alabama': 2.6414539212586647,
#  'Alaska': 0.0,
#  'Arizona': 2.9643998484922185,
#  'Arkansas': 2.309833091460811,
#  'California': 1.8542942330077685,
#  'Colorado': 1.3774771127873093,
#  'Connecticut': 2.8113531436269716,
#  'Delaware': 2.026734656858622,
#  'Florida': 1.7944802890604066,
#  'Georgia': 2.2408928015707166,
#  'Hawaii': 0.0,
#  'Idaho': 1.0947428804765198,
#  'Illinois': 2.4627548057482285,
#  'Indiana': 2.368632320609781,
#  'Iowa': 2.212696388658224,
#  'Kansas': 2.059163190398808,
#  'Louisiana': 2.7985167000407722,
#  'Maine': 0.0,
#  'Maryland': 1.6513089430598953,
#  'Michigan': 2.2073825910758536,
#  'Minnesota': 1.4140916352591022,
#  'Mississippi': 3.033585840030255,
#  'Missouri': 1.7881677912616467,
#  'Montana': 0.9254315055752621,
#  'Nebraska': 1.0322303607851557,
#  'Nevada': 1.9118880882680493,
#  'New Hampshire': 0.7319170737955389,
#  'New Jersey': 3.377476576918483,
#  'New Mexico': 2.373809475202949,
#  'New York': 2.6891763135695426,
#  'North Carolina': 1.4149844780919367,
#  'North Dakota': 2.6133235072369465,
#  'Ohio': 1.9669522937956252,
#  'Oklahoma': 1.5072411633590677,
#  'Oregon': 0.707295779542507,
#  'Rhode Island': 2.8378857750975524,
#  'South Carolina': 2.108071229810427,
#  'South Dakota': 2.2403516455942922,
#  'Tennessee': 2.1780690517587615,
#  'Texas': 2.043543901572844,
#  'Utah': 0.6154075274802538,
#  'Vermont': 0.0,
#  'Washington': 0.7798677656216612,
#  'West Virginia': 1.6808728436502507,
#  'Wisconsin': 1.5430365759675482,
#  'Wyoming': 0.0,
#  'Kentucky': 1.3401080261079845,
#  'Massachusetts': 2.756190040173646,
#  'Pennsylvania': 2.503274987730041,
#  'Virginia': 1.2804748652678526}

# %%
state_data = pd.DataFrame.from_dict(average_death_dict, orient='index')
state_data
# Out:
#                        0
# Alabama         2.641454
# Alaska          0.000000
# Arizona         2.964400
# Arkansas        2.309833
# California      1.854294
# Colorado        1.377477
# Connecticut     2.811353
# Delaware        2.026735
# Florida         1.794480
# Georgia         2.240893
# Hawaii          0.000000
# Idaho           1.094743
# Illinois        2.462755
# Indiana         2.368632
# Iowa            2.212696
# Kansas          2.059163
# Louisiana       2.798517
# Maine           0.000000
# Maryland        1.651309
# Michigan        2.207383
# Minnesota       1.414092
# Mississippi     3.033586
# Missouri        1.788168
# Montana         0.925432
# Nebraska        1.032230
# Nevada          1.911888
# New Hampshire   0.731917
# New Jersey      3.377477
# New Mexico      2.373809
# New York        2.689176
# North Carolina  1.414984
# North Dakota    2.613324
# Ohio            1.966952
# Oklahoma        1.507241
# Oregon          0.707296
# Rhode Island    2.837886
# South Carolina  2.108071
# South Dakota    2.240352
# Tennessee       2.178069
# Texas           2.043544
# Utah            0.615408
# Vermont         0.000000
# Washington      0.779868
# West Virginia   1.680873
# Wisconsin       1.543037
# Wyoming         0.000000
# Kentucky        1.340108
# Massachusetts   2.756190
# Pennsylvania    2.503275
# Virginia        1.280475

# %%
age_data = pd.read_csv('age_data.csv')

# %%
#age_data = age_data.drop(0)

# %%
age_data = age_data.set_index('Location')

# %%
combined_data = state_data.merge(age_data, left_index = True, right_index = True)

# %%
combined_data['55+'] = combined_data['65+'] + combined_data['Adults 55-64']

# %%
comparison_data = combined_data.iloc[:,[0,2]]
comparison_data
# Out:
#                        0  Adults 19-25
# Alabama         2.641454         0.087
# Alaska          0.000000         0.093
# Arizona         2.964400         0.093
# Arkansas        2.309833         0.087
# California      1.854294         0.092
# Colorado        1.377477         0.089
# Connecticut     2.811353         0.086
# Delaware        2.026735         0.081
# Florida         1.794480         0.080
# Georgia         2.240893         0.089
# Hawaii          0.000000         0.072
# Idaho           1.094743         0.085
# Illinois        2.462755         0.087
# Indiana         2.368632         0.091
# Iowa            2.212696         0.089
# Kansas          2.059163         0.092
# Louisiana       2.798517         0.088
# Maine           0.000000         0.075
# Maryland        1.651309         0.081
# Michigan        2.207383         0.091
# Minnesota       1.414092         0.082
# Mississippi     3.033586         0.089
# Missouri        1.788168         0.085
# Montana         0.925432         0.085
# Nebraska        1.032230         0.088
# Nevada          1.911888         0.083
# New Hampshire   0.731917         0.078
# New Jersey      3.377477         0.082
# New Mexico      2.373809         0.090
# New York        2.689176         0.086
# North Carolina  1.414984         0.086
# North Dakota    2.613324         0.102
# Ohio            1.966952         0.085
# Oklahoma        1.507241         0.091
# Oregon          0.707296         0.084
# Rhode Island    2.837886         0.088
# South Carolina  2.108071         0.082
# South Dakota    2.240352         0.082
# Tennessee       2.178069         0.086
# Texas           2.043544         0.094
# Utah            0.615408         0.109
# Vermont         0.000000         0.086
# Washington      0.779868         0.084
# West Virginia   1.680873         0.081
# Wisconsin       1.543037         0.085
# Wyoming         0.000000         0.083
# Kentucky        1.340108         0.089
# Massachusetts   2.756190         0.087
# Pennsylvania    2.503275         0.079
# Virginia        1.280475         0.084

# %%
comparison_data = comparison_data.rename(columns={0:'deaths'})

# %%
comparison_data
# Out:
#                   deaths  Adults 19-25
# Alabama         2.641454         0.087
# Alaska          0.000000         0.093
# Arizona         2.964400         0.093
# Arkansas        2.309833         0.087
# California      1.854294         0.092
# Colorado        1.377477         0.089
# Connecticut     2.811353         0.086
# Delaware        2.026735         0.081
# Florida         1.794480         0.080
# Georgia         2.240893         0.089
# Hawaii          0.000000         0.072
# Idaho           1.094743         0.085
# Illinois        2.462755         0.087
# Indiana         2.368632         0.091
# Iowa            2.212696         0.089
# Kansas          2.059163         0.092
# Louisiana       2.798517         0.088
# Maine           0.000000         0.075
# Maryland        1.651309         0.081
# Michigan        2.207383         0.091
# Minnesota       1.414092         0.082
# Mississippi     3.033586         0.089
# Missouri        1.788168         0.085
# Montana         0.925432         0.085
# Nebraska        1.032230         0.088
# Nevada          1.911888         0.083
# New Hampshire   0.731917         0.078
# New Jersey      3.377477         0.082
# New Mexico      2.373809         0.090
# New York        2.689176         0.086
# North Carolina  1.414984         0.086
# North Dakota    2.613324         0.102
# Ohio            1.966952         0.085
# Oklahoma        1.507241         0.091
# Oregon          0.707296         0.084
# Rhode Island    2.837886         0.088
# South Carolina  2.108071         0.082
# South Dakota    2.240352         0.082
# Tennessee       2.178069         0.086
# Texas           2.043544         0.094
# Utah            0.615408         0.109
# Vermont         0.000000         0.086
# Washington      0.779868         0.084
# West Virginia   1.680873         0.081
# Wisconsin       1.543037         0.085
# Wyoming         0.000000         0.083
# Kentucky        1.340108         0.089
# Massachusetts   2.756190         0.087
# Pennsylvania    2.503275         0.079
# Virginia        1.280475         0.084

# %%
sb.scatterplot(data=comparison_data,x = 'Adults 19-25' ,y = 'deaths')
# Out:
# <AxesSubplot:xlabel='Adults 19-25', ylabel='deaths'>

# %%
combined_data.corr()
# Out:
#                       0  Children 0-18  Adults 19-25  Adults 26-34  \
# 0              1.000000       0.028390      0.204720     -0.007977
# Children 0-18  0.028390       1.000000      0.644512      0.249457
# Adults 19-25   0.204720       0.644512      1.000000      0.435012
# Adults 26-34  -0.007977       0.249457      0.435012      1.000000
# Adults 35-54   0.059501      -0.291626     -0.276112      0.246643
# Adults 55-64  -0.064302      -0.834127     -0.654767     -0.513557
# 65+           -0.083168      -0.777154     -0.691184     -0.662831
# Total               NaN            NaN           NaN           NaN
# 55+           -0.081289      -0.848983     -0.721695     -0.648272
#
#                Adults 35-54  Adults 55-64       65+  Total       55+
# 0                  0.059501     -0.064302 -0.083168    NaN -0.081289
# Children 0-18     -0.291626     -0.834127 -0.777154    NaN -0.848983
# Adults 19-25      -0.276112     -0.654767 -0.691184    NaN -0.721695
# Adults 26-34       0.246643     -0.513557 -0.662831    NaN -0.648272
# Adults 35-54       1.000000      0.028506 -0.183161    NaN -0.113834
# Adults 55-64       0.028506      1.000000  0.745593    NaN  0.891047
# 65+               -0.183161      0.745593  1.000000    NaN  0.966845
# Total                   NaN           NaN       NaN    NaN       NaN
# 55+               -0.113834      0.891047  0.966845    NaN  1.000000
